# %%
#load libraries
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from sodapy import Socrata

# increase the size and quality of any plots we produce
import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 300

# %%
covid_df = pd.read_csv("data/COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv", low_memory = False)

# %%
covid_df.columns #column names
# Out:
# Index(['case_month', 'res_state', 'state_fips_code', 'res_county',
#        'county_fips_code', 'age_group', 'sex', 'race', 'ethnicity',
#        'case_positive_specimen_interval', 'case_onset_interval', 'process',
#        'exposure_yn', 'current_status', 'symptom_status', 'hosp_yn', 'icu_yn',
#        'death_yn', 'underlying_conditions_yn'],
#       dtype='object')

# %%
covid_df.dtypes
# Out:
# date                        datetime64[ns]
# state                               object
# state_fips_code                      int64
# county                              object
# county_fips_code                   float64
# age_group                           object
# sex                                 object
# race                                object
# ethnicity                           object
# symptom_status                      object
# hosp_yn                             object
# icu_yn                              object
# death_yn                            object
# underlying_conditions_yn            object
# dtype: object

# %%
covid_df.shape
# Out:
# (3068197, 19)

# %%
#data cleaning
covid_df["date"] = pd.to_datetime(covid_df["date"]) #convert to date

# %%
# dropping irrelevant columns
covid_df = covid_df.drop(columns=["case_positive_specimen_interval", "case_onset_interval", "process", "exposure_yn", "current_status"])

# %%
# rename cols for readability and uniformify across datasets
covid_rename = {"case_month":"date", "res_state":"state",
               "res_county":"county"}

covid_df = covid_df.rename(columns=covid_rename)

# %%
# converting data types 
to_str = ["state", "county", "age_group", "sex", "race", "ethnicity",
          "symptom_status", "hosp_yn", "icu_yn", "death_yn", "underlying_conditions_yn"]
covid_df[to_str] = covid_df[to_str].astype(str)

# %%
# show cols with NaNs
covid_df.columns[covid_df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
# fill NaNs in county_fips_code with "Not Available"
covid_df["county_fips_code"] = covid_df["county_fips_code"].fillna("Not Available")

# %%
# shows all values within the race col
covid_df.race.unique()

# rename nan, Missing, and Unknown to Not Available
rename_covid_nan = {"nan":"Not Available",
                     "Missing":"Not Available",
                     "Unknown":"Not Available"}
covid_df["race"] = covid_df["race"].replace(rename_covid_nan).astype(str)

# %%
# same treatment for ethnicity as the race col
covid_df.ethnicity.unique()

covid_df["ethnicity"] = covid_df["ethnicity"].replace(rename_covid_nan).astype(str)

# %%
covid_df["county"] = covid_df["county"].replace({"nan":"Not Available"})

# checking for NaN string values and replace with "Not Available" in remaining cols
covid_df.age_group.unique()
covid_df["age_group"] = covid_df["age_group"].replace({"nan":"Not Available", "Missing":"Not Available"}).astype(str)

covid_df["sex"] = covid_df["sex"].replace(rename_covid_nan).astype(str)

covid_df["death_yn"] = covid_df["death_yn"].replace(rename_covid_nan).astype(str)

covid_df["underlying_conditions_yn"] = covid_df["underlying_conditions_yn"].replace(rename_covid_nan).astype(str)

# %%
rename_missing_unk = {"Missing":"Not Available",
                      "Unknown":"Not Available"}
rename_col = ["symptom_status", "hosp_yn", "icu_yn"]
covid_df[rename_col] = covid_df[rename_col].replace(rename_missing_unk).astype(str)

# %%
covid_df.sample(10, random_state = 42)
# Out:
#               date state  state_fips_code       county county_fips_code  \
# 3035816 2021-01-01    NY               36        KINGS          36047.0
# 353013  2021-12-01    NY               36     CHENANGO          36017.0
# 2447365 2020-04-01    NY               36     NEW YORK          36061.0
# 1300224 2021-02-01    NY               36        KINGS          36047.0
# 658764  2020-09-01    NY               36   CHAUTAUQUA          36013.0
# 2463926 2021-02-01    NY               36       QUEENS          36081.0
# 438541  2021-01-01    NY               36  SCHENECTADY          36093.0
# 1242710 2021-02-01    NY               36         ERIE          36029.0
# 2580841 2021-01-01    NY               36       QUEENS          36081.0
# 1217306 2021-08-01    NY               36     RICHMOND          36085.0
#
#               age_group     sex           race            ethnicity  \
# 3035816  50 to 64 years  Female          White  Non-Hispanic/Latino
# 353013   18 to 49 years    Male          White  Non-Hispanic/Latino
# 2447365       65+ years    Male          White        Not Available
# 1300224  18 to 49 years  Female          White  Non-Hispanic/Latino
# 658764        65+ years  Female  Not Available        Not Available
# 2463926  18 to 49 years    Male  Not Available      Hispanic/Latino
# 438541   50 to 64 years  Female          White        Not Available
# 1242710  18 to 49 years  Female          White  Non-Hispanic/Latino
# 2580841       65+ years  Female          Asian  Non-Hispanic/Latino
# 1217306    0 - 17 years    Male  Not Available        Not Available
#
#         symptom_status        hosp_yn         icu_yn       death_yn  \
# 3035816    Symptomatic  Not Available  Not Available  Not Available
# 353013   Not Available  Not Available  Not Available             No
# 2447365  Not Available            Yes  Not Available  Not Available
# 1300224    Symptomatic  Not Available  Not Available  Not Available
# 658764   Not Available  Not Available  Not Available             No
# 2463926    Symptomatic  Not Available  Not Available  Not Available
# 438541     Symptomatic             No  Not Available             No
# 1242710    Symptomatic             No  Not Available             No
# 2580841  Not Available  Not Available  Not Available  Not Available
# 1217306    Symptomatic  Not Available  Not Available  Not Available
#
#         underlying_conditions_yn
# 3035816            Not Available
# 353013             Not Available
# 2447365                      Yes
# 1300224            Not Available
# 658764             Not Available
# 2463926            Not Available
# 438541             Not Available
# 1242710            Not Available
# 2580841                      Yes
# 1217306            Not Available

# %%
covid_df.describe(include = 'all',datetime_is_numeric=True) #describe and include string columns
# Out:
#                                  date    state  state_fips_code   county  \
# count                         3068197  3068197        3068197.0  3068197
# unique                            NaN        1              NaN       60
# top                               NaN       NY              NaN    KINGS
# freq                              NaN  3068197              NaN   393598
# mean    2021-01-26 14:13:51.516097536      NaN             36.0      NaN
# min               2020-01-01 00:00:00      NaN             36.0      NaN
# 25%               2020-10-01 00:00:00      NaN             36.0      NaN
# 50%               2021-01-01 00:00:00      NaN             36.0      NaN
# 75%               2021-08-01 00:00:00      NaN             36.0      NaN
# max               2021-12-01 00:00:00      NaN             36.0      NaN
# std                               NaN      NaN              0.0      NaN
#
#         county_fips_code       age_group      sex           race  \
# count          3068197.0         3068197  3068197        3068197
# unique              60.0               5        3              7
# top              36047.0  18 to 49 years   Female  Not Available
# freq            393598.0         1591113  1565104        1465777
# mean                 NaN             NaN      NaN            NaN
# min                  NaN             NaN      NaN            NaN
# 25%                  NaN             NaN      NaN            NaN
# 50%                  NaN             NaN      NaN            NaN
# 75%                  NaN             NaN      NaN            NaN
# max                  NaN             NaN      NaN            NaN
# std                  NaN             NaN      NaN            NaN
#
#             ethnicity symptom_status        hosp_yn         icu_yn death_yn  \
# count         3068197        3068197        3068197        3068197  3068197
# unique              3              3              3              3        3
# top     Not Available  Not Available  Not Available  Not Available       No
# freq          1781160        1872146        2481857        3033949  1607526
# mean              NaN            NaN            NaN            NaN      NaN
# min               NaN            NaN            NaN            NaN      NaN
# 25%               NaN            NaN            NaN            NaN      NaN
# 50%               NaN            NaN            NaN            NaN      NaN
# 75%               NaN            NaN            NaN            NaN      NaN
# max               NaN            NaN            NaN            NaN      NaN
# std               NaN            NaN            NaN            NaN      NaN
#
#        underlying_conditions_yn
# count                   3068197
# unique                        3
# top               Not Available
# freq                    2702595
# mean                        NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
# std                         NaN

# %%
sns.pairplot(covid_df)

# %%
#covid cases trend
trend_df = covid_df.groupby(['date']).size().reset_index(name = 'case_count').set_index('date')
trend_df['case_count_millions'] = trend_df['case_count']/1000000
plt.plot(trend_df.index,trend_df['case_count_millions'])
plt.title('COVID-19 Cases Have Spiked Twice But Is Now Trending Downards')
plt.xlabel('Date')
plt.ylabel('Case Count (Millions)')
plt.xticks(rotation=90)
plt.show()

# %%
covid_df.groupby(['race']).size().plot.bar()
plt.title("COVID-19 Cases by Race")
plt.show()

# %%
#death status per race
death_df = covid_df[covid_df['death_yn'] == 'Yes'] 
death_df.groupby(['race']).size().plot.bar()
plt.title("Deaths by Race")
plt.show()

# %%
#death status per state
death_df.groupby(['state']).size().reset_index(name = 'count')
# Out:
#   state  count
# 0    NY  37218

# %%
covid_df.groupby(["age_group"]).size().plot.bar()
plt.title("COVID-19 Cases by Age Group");
