# %% [markdown]
# # Which COVID-19 Vaccine is Best for You?
# ## DS4A Team 55 Preliminary EDA

# %%
import pandas as pd
import numpy as np
import math
import base64
import matplotlib.pyplot as plt
import seaborn as sns
from sodapy import Socrata

# %% [markdown]
# ### state_vax.csv
# Vaccine administration data for states within the U.S., including the District of Columbia from 12/13/2020 to the present, updated daily.

# %%
client = Socrata(
        domain = "data.cdc.gov",
        app_token = "bsYMLkKAQhIIVd7wzBzp5BiCR",
        timeout=10
        )
results = client.get_all("unsk-b7fc")

# convert to pandas DataFrame
df = pd.DataFrame.from_records(results)
df.sample(10)
# Out:
#                           date mmwr_week location distributed  \
# 11787  2021-07-09T00:00:00.000        27       AR     2867740
# 23993  2021-01-02T00:00:00.000        53       NJ      403975
# 9150   2021-08-19T00:00:00.000        33       MH       51300
# 19978  2021-03-05T00:00:00.000         9       CA    13609110
# 18269  2021-03-31T00:00:00.000        13       SD      618745
# 21931  2021-02-03T00:00:00.000         5       MA     1156375
# 8663   2021-08-26T00:00:00.000        34       NE     2326180
# 13630  2021-06-11T00:00:00.000        23       DE     1254385
# 5145   2021-10-19T00:00:00.000        42       CO     8604365
# 4770   2021-10-25T00:00:00.000        43       TX    43802845
#
#       distributed_janssen distributed_moderna distributed_pfizer  \
# 11787              178900             1297620            1391220
# 23993                   0                   0                  0
# 9150                10800               40500                  0
# 19978              114100             6884900            6610110
# 18269               21100              306900             290745
# 21931                   0                   0                  0
# 8663               108100              912300            1305780
# 13630               65800              510960             677625
# 5145               384500             3317040            4902825
# 4770              2127500            16834520           24840825
#
#       distributed_unk_manuf dist_per_100k distributed_per_100k_12plus  ...  \
# 11787                     0         95027                      112142  ...
# 23993                     0          4548                           0  ...
# 9150                      0         87823                      102839  ...
# 19978                     0         34443                           0  ...
# 18269                     0         69942                           0  ...
# 21931                     0         16777                           0  ...
# 8663                      0        120253                      143821  ...
# 13630                     0        128818                      149366  ...
# 5145                      0        149414                      174316  ...
# 4770                      0        151066                      181746  ...
#
#       administered_dose1_recip_5pluspop_pct series_complete_5plus  \
# 11787                                     0                     0
# 23993                                     0                     0
# 9150                                      0                     0
# 19978                                     0                     0
# 18269                                     0                     0
# 21931                                     0                     0
# 8663                                      0                     0
# 13630                                     0                     0
# 5145                                      0                     0
# 4770                                      0                     0
#
#       series_complete_5pluspop_pct administered_5plus admin_per_100k_5plus  \
# 11787                            0                  0                    0
# 23993                            0                  0                    0
# 9150                             0                  0                    0
# 19978                            0                  0                    0
# 18269                            0                  0                    0
# 21931                            0                  0                    0
# 8663                             0                  0                    0
# 13630                            0                  0                    0
# 5145                             0                  0                    0
# 4770                             0                  0                    0
#
#       distributed_per_100k_5plus series_complete_moderna_5plus  \
# 11787                          0                           NaN
# 23993                          0                           NaN
# 9150                           0                           NaN
# 19978                          0                           NaN
# 18269                          0                           NaN
# 21931                          0                           NaN
# 8663                           0                           NaN
# 13630                          0                           NaN
# 5145                           0                           NaN
# 4770                           0                           NaN
#
#       series_complete_pfizer_5plus series_complete_janssen_5plus  \
# 11787                          NaN                           NaN
# 23993                          NaN                           NaN
# 9150                           NaN                           NaN
# 19978                          NaN                           NaN
# 18269                          NaN                           NaN
# 21931                          NaN                           NaN
# 8663                           NaN                           NaN
# 13630                          NaN                           NaN
# 5145                           NaN                           NaN
# 4770                           NaN                           NaN
#
#       series_complete_unk_manuf_5plus
# 11787                             NaN
# 23993                             NaN
# 9150                              NaN
# 19978                             NaN
# 18269                             NaN
# 21931                             NaN
# 8663                              NaN
# 13630                             NaN
# 5145                              NaN
# 4770                              NaN
#
# [10 rows x 80 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25240 entries, 0 to 25239
# Data columns (total 80 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   date                                   25240 non-null  object
#  1   mmwr_week                              25240 non-null  object
#  2   location                               25240 non-null  object
#  3   distributed                            25240 non-null  object
#  4   distributed_janssen                    25240 non-null  object
#  5   distributed_moderna                    25240 non-null  object
#  6   distributed_pfizer                     25240 non-null  object
#  7   distributed_unk_manuf                  25240 non-null  object
#  8   dist_per_100k                          25240 non-null  object
#  9   distributed_per_100k_12plus            25240 non-null  object
#  10  distributed_per_100k_18plus            25240 non-null  object
#  11  distributed_per_100k_65plus            25240 non-null  object
#  12  administered                           25240 non-null  object
#  13  administered_12plus                    25240 non-null  object
#  14  administered_18plus                    25240 non-null  object
#  15  administered_65plus                    25240 non-null  object
#  16  administered_janssen                   25240 non-null  object
#  17  administered_moderna                   25240 non-null  object
#  18  administered_pfizer                    25240 non-null  object
#  19  administered_unk_manuf                 25240 non-null  object
#  20  admin_per_100k                         25240 non-null  object
#  21  admin_per_100k_12plus                  25240 non-null  object
#  22  admin_per_100k_18plus                  25240 non-null  object
#  23  admin_per_100k_65plus                  25240 non-null  object
#  24  recip_administered                     25240 non-null  object
#  25  administered_dose1_recip               25240 non-null  object
#  26  administered_dose1_pop_pct             25240 non-null  object
#  27  administered_dose1_recip_1             25240 non-null  object
#  28  administered_dose1_recip_2             25240 non-null  object
#  29  administered_dose1_recip_3             25240 non-null  object
#  30  administered_dose1_recip_4             25240 non-null  object
#  31  administered_dose1_recip_5             25240 non-null  object
#  32  administered_dose1_recip_6             25240 non-null  object
#  33  series_complete_yes                    25240 non-null  object
#  34  series_complete_pop_pct                25240 non-null  object
#  35  series_complete_12plus                 25240 non-null  object
#  36  series_complete_12pluspop              25240 non-null  object
#  37  series_complete_18plus                 25240 non-null  object
#  38  series_complete_18pluspop              25240 non-null  object
#  39  series_complete_65plus                 25240 non-null  object
#  40  series_complete_65pluspop              25240 non-null  object
#  41  series_complete_janssen                25240 non-null  object
#  42  series_complete_moderna                25240 non-null  object
#  43  series_complete_pfizer                 25240 non-null  object
#  44  series_complete_unk_manuf              25240 non-null  object
#  45  series_complete_janssen_12plus         25240 non-null  object
#  46  series_complete_moderna_12plus         25240 non-null  object
#  47  series_complete_pfizer_12plus          25240 non-null  object
#  48  series_complete_unk_manuf_1            25240 non-null  object
#  49  series_complete_janssen_18plus         25240 non-null  object
#  50  series_complete_moderna_18plus         25240 non-null  object
#  51  series_complete_pfizer_18plus          25240 non-null  object
#  52  series_complete_unk_manuf_2            25240 non-null  object
#  53  series_complete_janssen_65plus         25240 non-null  object
#  54  series_complete_moderna_65plus         25240 non-null  object
#  55  series_complete_pfizer_65plus          25240 non-null  object
#  56  series_complete_unk_manuf_3            25240 non-null  object
#  57  additional_doses                       8892 non-null   object
#  58  additional_doses_vax_pct               24915 non-null  object
#  59  additional_doses_18plus                24915 non-null  object
#  60  additional_doses_18plus_vax_pct        24915 non-null  object
#  61  additional_doses_50plus                24915 non-null  object
#  62  additional_doses_50plus_vax_pct        25240 non-null  object
#  63  additional_doses_65plus                24915 non-null  object
#  64  additional_doses_65plus_vax_pct        24915 non-null  object
#  65  additional_doses_moderna               24915 non-null  object
#  66  additional_doses_pfizer                24915 non-null  object
#  67  additional_doses_janssen               24915 non-null  object
#  68  additional_doses_unk_manuf             24915 non-null  object
#  69  administered_dose1_recip_5plus         24792 non-null  object
#  70  administered_dose1_recip_5pluspop_pct  24792 non-null  object
#  71  series_complete_5plus                  24792 non-null  object
#  72  series_complete_5pluspop_pct           24792 non-null  object
#  73  administered_5plus                     24792 non-null  object
#  74  admin_per_100k_5plus                   24792 non-null  object
#  75  distributed_per_100k_5plus             24792 non-null  object
#  76  series_complete_moderna_5plus          4224 non-null   object
#  77  series_complete_pfizer_5plus           4224 non-null   object
#  78  series_complete_janssen_5plus          4224 non-null   object
#  79  series_complete_unk_manuf_5plus        4224 non-null   object
# dtypes: object(80)
# memory usage: 15.4+ MB

# %%
# reset max_rows to default after viewing all 80 cols in above cell
pd.reset_option("display.max_rows")

# %%
# remove all distribution cols
# remove "Administered", this is the total for 1st dose and complete series
# remove all 5plus cols, very recently approved and sporadic across states
# remove additional doses for 50plus, age group doesn't show up elsewhere in dataset


df = df.drop(columns= ["mmwr_week","distributed", "distributed_janssen", "distributed_moderna", 
                       "distributed_pfizer", "distributed_unk_manuf", "dist_per_100k","distributed_per_100k_12plus",
                       "distributed_per_100k_18plus", "distributed_per_100k_65plus", "distributed_per_100k_5plus",
                       "administered","administered_dose1_recip_5plus",
                       "administered_dose1_recip_5pluspop_pct", "series_complete_5plus", "series_complete_5pluspop_pct", 
                       "administered_5plus", "admin_per_100k_5plus", "series_complete_moderna_5plus",
                       "series_complete_pfizer_5plus", "series_complete_janssen_5plus", "series_complete_unk_manuf_5plus",
                       "additional_doses_50plus", "additional_doses_50plus_vax_pct"], axis=1)
df
# Out:
#                           date location administered_12plus  \
# 0      2022-01-07T00:00:00.000       MA            12804509
# 1      2022-01-07T00:00:00.000       NH             2380531
# 2      2022-01-07T00:00:00.000       DE             1574933
# 3      2022-01-07T00:00:00.000       RI             1937516
# 4      2022-01-07T00:00:00.000       MN             8973718
# ...                        ...      ...                 ...
# 25235  2020-12-13T00:00:00.000       GU                   0
# 25236  2020-12-13T00:00:00.000      LTC                   0
# 25237  2020-12-13T00:00:00.000       VI                   0
# 25238  2020-12-13T00:00:00.000       MP                   0
# 25239  2020-12-13T00:00:00.000       AS                   0
#
#       administered_18plus administered_65plus administered_janssen  \
# 0                12024054             3074002               388247
# 1                 2241334              673701               109641
# 2                 1483717              493236                58750
# 3                 1824468              512794                62765
# 4                 8419230             2436961               346686
# ...                   ...                 ...                  ...
# 25235                   0                   0                    0
# 25236                   0                   0                    0
# 25237                   0                   0                    0
# 25238                   0                   0                    0
# 25239                   0                   0                    0
#
#       administered_moderna administered_pfizer administered_unk_manuf  \
# 0                  5223957             7619251                    425
# 1                   913219             1407458                     75
# 2                   624450              922700                   1879
# 3                   763485             1161845                   1415
# 4                  3417748             5515964                   3161
# ...                    ...                 ...                    ...
# 25235                    0                   0                      0
# 25236                    0                   0                      0
# 25237                    0                   0                      0
# 25238                    0                   0                      0
# 25239                    0                   0                      0
#
#       admin_per_100k  ... additional_doses additional_doses_vax_pct  \
# 0             191975  ...          2115081                     40.9
# 1             178743  ...           135347                     14.7
# 2             165110  ...           227598                     36.2
# 3             187803  ...           366932                     44.9
# 4             164613  ...          1795358                     48.3
# ...              ...  ...              ...                      ...
# 25235              0  ...              NaN                        0
# 25236              0  ...              NaN                        0
# 25237              0  ...              NaN                        0
# 25238              0  ...              NaN                        0
# 25239              0  ...              NaN                        0
#
#       additional_doses_18plus additional_doses_18plus_vax_pct  \
# 0                     2090293                              45
# 1                      134085                            15.8
# 2                      225869                            39.1
# 3                      362676                            49.1
# 4                     1777334                            53.5
# ...                       ...                             ...
# 25235                       0                               0
# 25236                       0                               0
# 25237                       0                               0
# 25238                       0                               0
# 25239                       0                               0
#
#       additional_doses_65plus additional_doses_65plus_vax_pct  \
# 0                      698620                            64.3
# 1                       47207                            20.1
# 2                      107078                              61
# 3                      132865                            72.4
# 4                      671341                            76.9
# ...                       ...                             ...
# 25235                       0                               0
# 25236                       0                               0
# 25237                       0                               0
# 25238                       0                               0
# 25239                       0                               0
#
#       additional_doses_moderna additional_doses_pfizer  \
# 0                      1034824                 1058702
# 1                        63648                   68523
# 2                       100569                  123184
# 3                       162343                  200423
# 4                       742018                 1027490
# ...                        ...                     ...
# 25235                        0                       0
# 25236                        0                       0
# 25237                        0                       0
# 25238                        0                       0
# 25239                        0                       0
#
#       additional_doses_janssen additional_doses_unk_manuf
# 0                        21547                          8
# 1                         3166                         10
# 2                         3832                         13
# 3                         4144                         22
# 4                        25598                        252
# ...                        ...                        ...
# 25235                        0                          0
# 25236                        0                          0
# 25237                        0                          0
# 25238                        0                          0
# 25239                        0                          0
#
# [25240 rows x 56 columns]

# %%
# abbreviating column names for readability
# cols in api data are labelled differently than csv directly from data.cdc.gov, values match up so renaming those cols

rename_cols = {"administered_12plus":"admin_12plus", 
               "administered_18plus":"admin_18plus",
               "administered_65plus":"admin_65plus",
               "administered_janssen":"admin_janssen",
               "administered_moderna":"admin_moderna",
               "administered_pfizer":"admin_pfizer",
               "administered_unk_manuf":"admin_unk",
               "recip_administered":"recip_admin",
               "administered_dose1_recip":"admin_dose1",
               "administered_dose1_pop_pct":"admin_dose1_pop_pct",
               "administered_dose1_recip_1":"admin_dose1_12plus",
               "administered_dose1_recip_2":"admin_dose1_12plus_pop_pct",
               "administered_dose1_recip_3":"admin_dose1_18plus",
               "administered_dose1_recip_4":"admin_dose1_18plus_pop_pct",
               "administered_dose1_recip_5":"admin_dose1_65plus",
               "administered_dose1_recip_6":"admin_dose1_65plus_pop_pct",
               "series_complete_yes":"series_complete",
               "series_complete_12pluspop":"series_complete_12plus_pop_pct",
               "series_complete_18pluspop":"series_complete_18plus_pop_pct",
               "series_complete_65pluspop":"series_complete_65plus_pop_pct",
               "series_complete_unk_manuf":"series_complete_unk",
               "series_complete_unk_manuf_1":"series_complete_unk_12plus",
               "series_complete_unk_manuf_2":"series_complete_unk_18plus",
               "series_complete_unk_manuf_3":"series_complete_unk_65plus",
               "series_complete_12pluspop_pct":"series_complete_12plus_pop_pct",
               "series_complete_18pluspop_pct":"series_complete_18plus_pop_pct",
               "series_complete_65pluspop_pct":"series_complete_65plus_pop_pct"
               }
df = df.rename(columns=rename_cols)

# %%
df.columns
# Out:
# Index(['date', 'location', 'admin_12plus', 'admin_18plus', 'admin_65plus',
#        'admin_janssen', 'admin_moderna', 'admin_pfizer', 'admin_unk',
#        'admin_per_100k', 'admin_per_100k_12plus', 'admin_per_100k_18plus',
#        'admin_per_100k_65plus', 'recip_admin', 'admin_dose1',
#        'admin_dose1_pop_pct', 'admin_dose1_12plus',
#        'admin_dose1_12plus_pop_pct', 'admin_dose1_18plus',
#        'admin_dose1_18plus_pop_pct', 'admin_dose1_65plus',
#        'admin_dose1_65plus_pop_pct', 'series_complete',
#        'series_complete_pop_pct', 'series_complete_12plus',
#        'series_complete_12plus_pop_pct', 'series_complete_18plus',
#        'series_complete_18plus_pop_pct', 'series_complete_65plus',
#        'series_complete_65plus_pop_pct', 'series_complete_janssen',
#        'series_complete_moderna', 'series_complete_pfizer',
#        'series_complete_unk', 'series_complete_janssen_12plus',
#        'series_complete_moderna_12plus', 'series_complete_pfizer_12plus',
#        'series_complete_unk_12plus', 'series_complete_janssen_18plus',
#        'series_complete_moderna_18plus', 'series_complete_pfizer_18plus',
#        'series_complete_unk_18plus', 'series_complete_janssen_65plus',
#        'series_complete_moderna_65plus', 'series_complete_pfizer_65plus',
#        'series_complete_unk_65plus', 'additional_doses',
#        'additional_doses_vax_pct', 'additional_doses_18plus',
#        'additional_doses_18plus_vax_pct', 'additional_doses_65plus',
#        'additional_doses_65plus_vax_pct', 'additional_doses_moderna',
#        'additional_doses_pfizer', 'additional_doses_janssen',
#        'additional_doses_unk_manuf'],
#       dtype='object')

# %%
df.dtypes
# Out:
# date                               object
# location                           object
# admin_12plus                       object
# admin_18plus                       object
# admin_65plus                       object
# admin_janssen                      object
# admin_moderna                      object
# admin_pfizer                       object
# admin_unk                          object
# admin_per_100k                     object
# admin_per_100k_12plus              object
# admin_per_100k_18plus              object
# admin_per_100k_65plus              object
# recip_admin                        object
# admin_dose1                        object
# admin_dose1_pop_pct                object
# admin_dose1_12plus                 object
# admin_dose1_12plus_pop_pct         object
# admin_dose1_18plus                 object
# admin_dose1_18plus_pop_pct         object
# admin_dose1_65plus                 object
# admin_dose1_65plus_pop_pct         object
# series_complete                    object
# series_complete_pop_pct            object
# series_complete_12plus             object
# series_complete_12plus_pop_pct     object
# series_complete_18plus             object
# series_complete_18plus_pop_pct     object
# series_complete_65plus             object
# series_complete_65plus_pop_pct     object
# series_complete_janssen            object
# series_complete_moderna            object
# series_complete_pfizer             object
# series_complete_unk                object
# series_complete_janssen_12plus     object
# series_complete_moderna_12plus     object
# series_complete_pfizer_12plus      object
# series_complete_unk_12plus         object
# series_complete_janssen_18plus     object
# series_complete_moderna_18plus     object
# series_complete_pfizer_18plus      object
# series_complete_unk_18plus         object
# series_complete_janssen_65plus     object
# series_complete_moderna_65plus     object
# series_complete_pfizer_65plus      object
# series_complete_unk_65plus         object
# additional_doses                   object
# additional_doses_vax_pct           object
# additional_doses_18plus            object
# additional_doses_18plus_vax_pct    object
# additional_doses_65plus            object
# additional_doses_65plus_vax_pct    object
# additional_doses_moderna           object
# additional_doses_pfizer            object
# additional_doses_janssen           object
# additional_doses_unk_manuf         object
# dtype: object

# %%
# show cols with NaNs
# cols with NaNs are additional dose cols, after investigating this happens when other additional dose cols are 0
df.columns[df.isnull().any()]
# Out:
# Index(['additional_doses', 'additional_doses_vax_pct',
#        'additional_doses_18plus', 'additional_doses_18plus_vax_pct',
#        'additional_doses_65plus', 'additional_doses_65plus_vax_pct',
#        'additional_doses_moderna', 'additional_doses_pfizer',
#        'additional_doses_janssen', 'additional_doses_unk_manuf'],
#       dtype='object')

# %%
# replace NaNs with 0 to fill in values
nan_col = ['additional_doses', 'additional_doses_vax_pct',
           'additional_doses_18plus', 'additional_doses_18plus_vax_pct',
           'additional_doses_65plus', 'additional_doses_65plus_vax_pct',
           'additional_doses_moderna', 'additional_doses_pfizer',
           'additional_doses_janssen', 'additional_doses_unk_manuf']
df[nan_col] = df[nan_col].fillna(0)

# %%
to_int = ['admin_12plus', 'admin_18plus', 'admin_65plus','admin_janssen',
          'admin_moderna', 'admin_pfizer', 'admin_unk','admin_per_100k',
          'admin_per_100k_12plus', 'admin_per_100k_18plus','admin_per_100k_65plus',
          'recip_admin', 'admin_dose1', 'admin_dose1_12plus', 'admin_dose1_18plus',
          'admin_dose1_65plus', 'series_complete_12plus', 'series_complete_18plus',
          'series_complete','series_complete_65plus', 'series_complete_janssen', 'series_complete_moderna',
          'series_complete_pfizer','series_complete_unk', 'series_complete_janssen_12plus',
          'series_complete_moderna_12plus', 'series_complete_pfizer_12plus', 'series_complete_unk_12plus',
          'series_complete_janssen_18plus', 'series_complete_moderna_18plus', 'series_complete_pfizer_18plus',
          'series_complete_unk_18plus', 'series_complete_janssen_65plus', 'series_complete_moderna_65plus',
          'series_complete_pfizer_65plus', 'series_complete_unk_65plus', 'additional_doses',
          'additional_doses_18plus', 'additional_doses_65plus', 'additional_doses_moderna',
          'additional_doses_pfizer', 'additional_doses_janssen', 'additional_doses_unk_manuf'
         ]

to_float = ['admin_dose1_pop_pct', 'admin_dose1_12plus_pop_pct', 'admin_dose1_18plus_pop_pct',
            'admin_dose1_65plus_pop_pct', 'series_complete_pop_pct', 'series_complete_12plus_pop_pct',
            'series_complete_12plus_pop_pct', 'series_complete_18plus_pop_pct', 'series_complete_65plus_pop_pct',
            'additional_doses_vax_pct', 'additional_doses_18plus_vax_pct', 'additional_doses_65plus_vax_pct'
           ]

df[to_int] = df[to_int].astype("int")
df[to_float] = df[to_float].astype("float")

# %%
# removing locations outside of the contential united states as well as united states total

drop_location = ["AS", "BP2", "DD2", "FM", "GU",
                 "IH2", "MH", "MP", "PR", "RP",
                 "US", "VA2", "VI", "LTC"]
df = df[~df["location"].isin(drop_location)]

# checking that location vals = 51, including DC

df.location.nunique()
# Out:
# 51

# %%
df.dtypes
# Out:
# date                                object
# location                            object
# admin_12plus                         int64
# admin_18plus                         int64
# admin_65plus                         int64
# admin_janssen                        int64
# admin_moderna                        int64
# admin_pfizer                         int64
# admin_unk                            int64
# admin_per_100k                       int64
# admin_per_100k_12plus                int64
# admin_per_100k_18plus                int64
# admin_per_100k_65plus                int64
# recip_admin                          int64
# admin_dose1                          int64
# admin_dose1_pop_pct                float64
# admin_dose1_12plus                   int64
# admin_dose1_12plus_pop_pct         float64
# admin_dose1_18plus                   int64
# admin_dose1_18plus_pop_pct         float64
# admin_dose1_65plus                   int64
# admin_dose1_65plus_pop_pct         float64
# series_complete                      int64
# series_complete_pop_pct            float64
# series_complete_12plus               int64
# series_complete_12plus_pop_pct     float64
# series_complete_18plus               int64
# series_complete_18plus_pop_pct     float64
# series_complete_65plus               int64
# series_complete_65plus_pop_pct     float64
# series_complete_janssen              int64
# series_complete_moderna              int64
# series_complete_pfizer               int64
# series_complete_unk                  int64
# series_complete_janssen_12plus       int64
# series_complete_moderna_12plus       int64
# series_complete_pfizer_12plus        int64
# series_complete_unk_12plus           int64
# series_complete_janssen_18plus       int64
# series_complete_moderna_18plus       int64
# series_complete_pfizer_18plus        int64
# series_complete_unk_18plus           int64
# series_complete_janssen_65plus       int64
# series_complete_moderna_65plus       int64
# series_complete_pfizer_65plus        int64
# series_complete_unk_65plus           int64
# additional_doses                     int64
# additional_doses_vax_pct           float64
# additional_doses_18plus              int64
# additional_doses_18plus_vax_pct    float64
# additional_doses_65plus              int64
# additional_doses_65plus_vax_pct    float64
# additional_doses_moderna             int64
# additional_doses_pfizer              int64
# additional_doses_janssen             int64
# additional_doses_unk_manuf           int64
# dtype: object

# %%
# converting "date" col to datetime
df["date"] = pd.to_datetime(df["date"])

# %%
# filter location to New York
df_ny = df.loc[df["location"] == "NY"]

# %%
# set index to date to extract rows for the first of each month, aligns with how other datasets are reported
df_ny_m = df_ny.set_index("date")
df_ny_m = df_ny_m.groupby(df_ny_m.index.strftime("%Y-%m")).tail(1)
df_ny_m.head(30)
# Out:
#            location  admin_12plus  admin_18plus  admin_65plus  admin_janssen  \
# date
# 2022-01-01       NY      33729902      31773550       7970310        1348370
# 2021-12-01       NY      29780989      27946653       7038182        1245561
# 2021-11-01       NY      27672902      25904827       6358360        1179846
# 2021-10-01       NY      25961184      24306764       5831882        1127289
# 2021-09-01       NY      24426700      22985019       5633411        1072305
# 2021-08-01       NY      22995942      21813875       5488352        1013560
# 2021-07-01       NY      21849369      20873295       5370845         948791
# 2021-06-01       NY      19706068      19188844       5168904         828036
# 2021-05-01       NY             0      15705472       4733041         603095
# 2021-04-01       NY             0       9369873       3570327         216370
# 2021-03-01       NY             0       4353823             0              0
# 2021-02-01       NY             0             0             0              0
# 2021-01-01       NY             0             0             0              0
# 2020-12-14       NY             0             0             0              0
#
#             admin_moderna  admin_pfizer  admin_unk  admin_per_100k  \
# date
# 2022-01-01       12653266      20488081      15751          177374
# 2021-12-01       11046085      17722694      11816          154348
# 2021-11-01       10090429      16394605      10689          142265
# 2021-10-01        9695417      15131586       9364          133465
# 2021-09-01        9356997      13991672       7909          125575
# 2021-08-01        9040360      12937436       6485          118219
# 2021-07-01        8743524      12153595       5114          112324
# 2021-06-01        8151594      10723586       4162          101305
# 2021-05-01        6819234       8433328       2942           81520
# 2021-04-01        4309912       4865934       1268           48287
# 2021-03-01        2253872       2101216        456           22389
# 2021-02-01         943356        984098        211            9909
# 2021-01-01          82248        146240         11            1175
# 2020-12-14              0             0          0               0
#
#             admin_per_100k_12plus  ...  additional_doses  \
# date                               ...
# 2022-01-01                 201094  ...           4686613
# 2021-12-01                 177551  ...           2053051
# 2021-11-01                 164983  ...            785287
# 2021-10-01                 154778  ...                 0
# 2021-09-01                 145629  ...                 0
# 2021-08-01                 137099  ...                 0
# 2021-07-01                 130263  ...                 0
# 2021-06-01                 117485  ...                 0
# 2021-05-01                      0  ...                 0
# 2021-04-01                      0  ...                 0
# 2021-03-01                      0  ...                 0
# 2021-02-01                      0  ...                 0
# 2021-01-01                      0  ...                 0
# 2020-12-14                      0  ...                 0
#
#             additional_doses_vax_pct  additional_doses_18plus  \
# date
# 2022-01-01                      33.5                  4648178
# 2021-12-01                      15.4                  2051249
# 2021-11-01                       6.0                   784264
# 2021-10-01                       0.0                        0
# 2021-09-01                       0.0                        0
# 2021-08-01                       0.0                        0
# 2021-07-01                       0.0                        0
# 2021-06-01                       0.0                        0
# 2021-05-01                       0.0                        0
# 2021-04-01                       0.0                        0
# 2021-03-01                       0.0                        0
# 2021-02-01                       0.0                        0
# 2021-01-01                       0.0                        0
# 2020-12-14                       0.0                        0
#
#             additional_doses_18plus_vax_pct  additional_doses_65plus  \
# date
# 2022-01-01                             36.3                  1719843
# 2021-12-01                             16.5                   992302
# 2021-11-01                              6.5                   469195
# 2021-10-01                              0.0                        0
# 2021-09-01                              0.0                        0
# 2021-08-01                              0.0                        0
# 2021-07-01                              0.0                        0
# 2021-06-01                              0.0                        0
# 2021-05-01                              0.0                        0
# 2021-04-01                              0.0                        0
# 2021-03-01                              0.0                        0
# 2021-02-01                              0.0                        0
# 2021-01-01                              0.0                        0
# 2020-12-14                              0.0                        0
#
#             additional_doses_65plus_vax_pct  additional_doses_moderna  \
# date
# 2022-01-01                             58.7                   2082738
# 2021-12-01                             34.6                    876774
# 2021-11-01                             16.6                    187754
# 2021-10-01                              0.0                         0
# 2021-09-01                              0.0                         0
# 2021-08-01                              0.0                         0
# 2021-07-01                              0.0                         0
# 2021-06-01                              0.0                         0
# 2021-05-01                              0.0                         0
# 2021-04-01                              0.0                         0
# 2021-03-01                              0.0                         0
# 2021-02-01                              0.0                         0
# 2021-01-01                              0.0                         0
# 2020-12-14                              0.0                         0
#
#             additional_doses_pfizer  additional_doses_janssen  \
# date
# 2022-01-01                  2522950                     80678
# 2021-12-01                  1149165                     27072
# 2021-11-01                   593410                      4102
# 2021-10-01                        0                         0
# 2021-09-01                        0                         0
# 2021-08-01                        0                         0
# 2021-07-01                        0                         0
# 2021-06-01                        0                         0
# 2021-05-01                        0                         0
# 2021-04-01                        0                         0
# 2021-03-01                        0                         0
# 2021-02-01                        0                         0
# 2021-01-01                        0                         0
# 2020-12-14                        0                         0
#
#             additional_doses_unk_manuf
# date
# 2022-01-01                         247
# 2021-12-01                          40
# 2021-11-01                          21
# 2021-10-01                           0
# 2021-09-01                           0
# 2021-08-01                           0
# 2021-07-01                           0
# 2021-06-01                           0
# 2021-05-01                           0
# 2021-04-01                           0
# 2021-03-01                           0
# 2021-02-01                           0
# 2021-01-01                           0
# 2020-12-14                           0
#
# [14 rows x 55 columns]

# %%
# first reported date and most recent date for vax data, updated daily
print(df_ny["date"].min())
print(df_ny["date"].max())
# Out:
# 2020-12-14 00:00:00
# 2022-01-07 00:00:00

# %%
# trend in administration of each vax manufacturer 
ny_m_plt = df_ny_m.reset_index()
ny_m_plt.plot(x="date", y=["admin_janssen", "admin_moderna", "admin_pfizer", "admin_unk"], kind="line")
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### covid_cases

# %% [markdown]
# ### census_data

# %% [markdown]
# ### percent_vaccinated_race & percent_cases_race

# %% [markdown]
# ### vaers
